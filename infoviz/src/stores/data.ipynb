# %%
import json

with open("data.json", "r") as file:
    data = json.load(file)

data['data']
# Out:
# {'SH': {'id': 1,
#   'name': 'Schleswig-Holstein',
#   'history': [{'cases': 0, 'date': '2020-01-01T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-02T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-03T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-04T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-05T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-06T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-07T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-08T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-09T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-10T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-11T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-12T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-13T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-14T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-15T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-16T00:00:00.000Z'},
#    {'cases': 0, 'date': '2020-01-17T00:00:00.000Z'},
# ...

# %%
for element in data['data'].values():
    print(element['name'])
# Out:
# Schleswig-Holstein
# Hamburg
# Niedersachsen
# Bremen
# Nordrhein-Westfalen
# Hessen
# Rheinland-Pfalz
# Baden-Württemberg
# Bayern
# Saarland
# Berlin
# Brandenburg
# Mecklenburg-Vorpommern
# Sachsen
# Sachsen-Anhalt
# Thüringen
